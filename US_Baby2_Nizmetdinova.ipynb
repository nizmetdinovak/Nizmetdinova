# %% [markdown]
# # US Baby Names

# %% [markdown]
# ### 1. Подключение библиотек

# %% [markdown]
# ##### Импортируйте необходимые библиотеки

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### 2. Загрузка данных

# %% [markdown]
# ##### Импортируйте набор данных и присвойте его переменной с именем baby_names

# %%
addr = 'US_Baby_Names_right.csv'
baby_names = pd.read_csv(addr)

# %% [markdown]
# ##### Посмотрите первые 10 записей.

# %%
baby_names
# Out:
#          Unnamed: 0       Id     Name  Year Gender State  Count
# 0             11349    11350     Emma  2004      F    AK     62
# 1             11350    11351  Madison  2004      F    AK     48
# 2             11351    11352   Hannah  2004      F    AK     46
# 3             11352    11353    Grace  2004      F    AK     44
# 4             11353    11354    Emily  2004      F    AK     41
# ...             ...      ...      ...   ...    ...   ...    ...
# 1016390     5647421  5647422     Seth  2014      M    WY      5
# 1016391     5647422  5647423  Spencer  2014      M    WY      5
# 1016392     5647423  5647424     Tyce  2014      M    WY      5
# 1016393     5647424  5647425   Victor  2014      M    WY      5
# 1016394     5647425  5647426   Waylon  2014      M    WY      5
#
# [1016395 rows x 7 columns]

# %% [markdown]
# ##### Выведите размерность и краткую информацию о наборе данных

# %%
baby_names.shape
# Out:
# (1016395, 7)

# %%
baby_names.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1016395 entries, 0 to 1016394
# Data columns (total 7 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   Unnamed: 0  1016395 non-null  int64
#  1   Id          1016395 non-null  int64
#  2   Name        1016395 non-null  object
#  3   Year        1016395 non-null  int64
#  4   Gender      1016395 non-null  object
#  5   State       1016395 non-null  object
#  6   Count       1016395 non-null  int64
# dtypes: int64(4), object(3)
# memory usage: 42.6+ MB

# %% [markdown]
# ### 3.Описание полей набора данных

# %% [markdown]
# ![Снимок экрана 2025-09-23 210328.png](attachment:36fb484b-d7e3-466b-b270-db38734e1b23.png)

# %% [markdown]
# ##### Выведите краткую статистическую информацию по набору данных

# %%
baby_names.describe(include = 'object')
# Out:
#            Name   Gender    State
# count   1016395  1016395  1016395
# unique    17632        2       51
# top       Riley        F       CA
# freq       1112   558846    76781

# %%
baby_names.describe()
# Out:
#         Unnamed: 0           Id         Year        Count
# count 1016395.0000 1016395.0000 1016395.0000 1016395.0000
# mean  2830990.4619 2830991.4619    2009.0532      34.8501
# std   1652475.6515 1652475.6515       3.1383      97.3973
# min     11349.0000   11350.0000    2004.0000       5.0000
# 25%   1317326.5000 1317327.5000    2006.0000       7.0000
# 50%   2811920.0000 2811921.0000    2009.0000      11.0000
# 75%   4242554.5000 4242555.5000    2012.0000      26.0000
# max   5647425.0000 5647426.0000    2014.0000    4167.0000

# %%
np.set_printoptions(suppress=True)
pd.set_option('display.float_format', lambda x: '%0.4f' % x)

# %%
baby_names.describe()
# Out:
#         Unnamed: 0           Id         Year        Count
# count 1016395.0000 1016395.0000 1016395.0000 1016395.0000
# mean  2830990.4619 2830991.4619    2009.0532      34.8501
# std   1652475.6515 1652475.6515       3.1383      97.3973
# min     11349.0000   11350.0000    2004.0000       5.0000
# 25%   1317326.5000 1317327.5000    2006.0000       7.0000
# 50%   2811920.0000 2811921.0000    2009.0000      11.0000
# 75%   4242554.5000 4242555.5000    2012.0000      26.0000
# max   5647425.0000 5647426.0000    2014.0000    4167.0000

# %% [markdown]
# ##### Напишите краткий вывод о наборе данных

# %% [markdown]
# Данный датасет содержит 1 016 395 записей, распределённых по четырём числовым столбцам,
# и охватывает период с 2004 по 2014 год включительно.

# %% [markdown]
# ##### Удалите столбец «Без имени: 0» и «Идентификатор»

# %%
baby_names = baby_names.drop(columns=['Unnamed: 0', 'Id'])

# %% [markdown]
# ##### Проверьте результат выполнения операции удаления. Выведите первые 5 записей, последние 5 записей и случайные 5 записей

# %%
baby_names.head(5)
# Out:
#       Name  Year Gender State  Count
# 0     Emma  2004      F    AK     62
# 1  Madison  2004      F    AK     48
# 2   Hannah  2004      F    AK     46
# 3    Grace  2004      F    AK     44
# 4    Emily  2004      F    AK     41

# %%
baby_names.tail(5)
# Out:
#             Name  Year Gender State  Count
# 1016390     Seth  2014      M    WY      5
# 1016391  Spencer  2014      M    WY      5
# 1016392     Tyce  2014      M    WY      5
# 1016393   Victor  2014      M    WY      5
# 1016394   Waylon  2014      M    WY      5

# %%
baby_names.sample(5)
# Out:
#            Name  Year Gender State  Count
# 795380    Aliza  2009      F    RI      5
# 525629  Jazmine  2008      F    MS     14
# 802490   Aliyah  2008      F    SC     29
# 334461    Amiya  2006      F    IN     16
# 989322    Bella  2008      F    WI     41

# %% [markdown]
# ### Проверка на наличие пропущенных и дублирующих значений

# %% [markdown]
# ##### Проверьте набор данных на наличие пропущенных значений

# %%
baby_names.isnull().sum()
# Out:
# Name      0
# Year      0
# Gender    0
# State     0
# Count     0
# dtype: int64

# %% [markdown]
# ##### Проверьте набор данных на наличие дублирующих значений

# %%
print(baby_names.duplicated().sum())
# Out:
# 0

# %% [markdown]
# ##### Удалите дублирующие значения ии проверьте размерность набора данных. Напишите краткий вывод

# %%
baby_names.drop_duplicates()
# Out:
#             Name  Year Gender State  Count
# 0           Emma  2004      F    AK     62
# 1        Madison  2004      F    AK     48
# 2         Hannah  2004      F    AK     46
# 3          Grace  2004      F    AK     44
# 4          Emily  2004      F    AK     41
# ...          ...   ...    ...   ...    ...
# 1016390     Seth  2014      M    WY      5
# 1016391  Spencer  2014      M    WY      5
# 1016392     Tyce  2014      M    WY      5
# 1016393   Victor  2014      M    WY      5
# 1016394   Waylon  2014      M    WY      5
#
# [1016395 rows x 5 columns]

# %%
baby_names.shape
# Out:
# (1016395, 5)

# %% [markdown]
# Краткий вывод: в наборе данных нет повторяющихся и пустых строк, а теперь ещё и нет столбцов Unnamed: 0	и Id.

# %% [markdown]
# ### Анализ данных

# %% [markdown]
# Выполните ниже указанные задания. По результатам каждого выполненного задания необходимо сделать вывод

# %% [markdown]
# ##### Каких имен в наборе данных больше: мужских или женских?

# %%
baby_name = baby_names['Gender'].value_counts()
baby_name
# Out:
# Gender
# F    558846
# M    457549
# Name: count, dtype: int64

# %%
baby_names['Gender'].value_counts().to_frame()
# Out:
#          count
# Gender
# F       558846
# M       457549

# %%
baby_names.sort_values('Gender')
# Out:
#             Name  Year Gender State  Count
# 0           Emma  2004      F    AK     62
# 580540    Kendra  2008      F    NE     10
# 580541    Kenzie  2008      F    NE     10
# 580542     Laura  2008      F    NE     10
# 580543     Macie  2008      F    NE     10
# ...          ...   ...    ...   ...    ...
# 612570    Aarush  2006      M    NJ      5
# 612569     Zymir  2006      M    NJ      6
# 612568   Yehudah  2006      M    NJ      6
# 612582     Arian  2006      M    NJ      5
# 1016394   Waylon  2014      M    WY      5
#
# [1016395 rows x 5 columns]

# %%
baby_names.groupby('Gender')['Count'].sum()
# Out:
# Gender
# F    16380293
# M    19041199
# Name: Count, dtype: int64

# %% [markdown]
# ##### Выведите информацию о рождаемости детей в США по годам. Для сортировки данных используйте функции sotr_index() и sort_values()

# %%
print(baby_names['Year'].value_counts().sort_index())
# Out:
# Year
# 2004    86420
# 2005    88494
# 2006    91803
# 2007    94332
# 2008    94970
# 2009    94609
# 2010    93307
# 2011    92545
# 2012    93024
# 2013    92743
# 2014    94148
# Name: count, dtype: int64

# %% [markdown]
# По году

# %%
print(baby_names['Year'].value_counts().sort_values())
# Out:
# Year
# 2004    86420
# 2005    88494
# 2006    91803
# 2011    92545
# 2013    92743
# 2012    93024
# 2010    93307
# 2014    94148
# 2007    94332
# 2009    94609
# 2008    94970
# Name: count, dtype: int64

# %% [markdown]
# По количеству

# %% [markdown]
# ##### Выведите информацию о рождаемости детей в США по штатам. Для сортировки данных используйте функции sotr_index() и sort_values()

# %%
baby_names.groupby('State')['Count'].sum().sort_index()
# Out:
# State
# AK      63649
# AL     475422
# AR     292659
# AZ     808258
# CA    5084647
# CO     574230
# CT     312747
# DC      82504
# DE      73060
# FL    1976379
# GA    1185168
# HI      90406
# IA     318773
# ID     167128
# IL    1486991
# IN     753487
# KS     327040
# KY     460790
# LA     493505
# MA     638232
# MD     585246
# ME      99368
# MI    1038080
# MN     595801
# MO     672772
# MS     288143
# MT      75765
# NC    1078680
# ND      69561
# NE     201367
# NH     101547
# NJ     913330
# NM     198657
# NV     279767
# NY    2208154
# OH    1286370
# OK     413580
# OR     381556
# PA    1276091
# RI      83499
# SC     435359
# SD      79547
# TN     735102
# TX    3791675
# UT     448216
# VA     872376
# VT      36432
# WA     730321
# WI     576679
# WV     167357
# WY      36019
# Name: Count, dtype: int64

# %%
baby_names.groupby('State')['Count'].sum().sort_values()
# Out:
# State
# WY      36019
# VT      36432
# AK      63649
# ND      69561
# DE      73060
# MT      75765
# SD      79547
# DC      82504
# RI      83499
# HI      90406
# ME      99368
# NH     101547
# ID     167128
# WV     167357
# NM     198657
# NE     201367
# NV     279767
# MS     288143
# AR     292659
# CT     312747
# IA     318773
# KS     327040
# OR     381556
# OK     413580
# SC     435359
# UT     448216
# KY     460790
# AL     475422
# LA     493505
# CO     574230
# WI     576679
# MD     585246
# MN     595801
# MA     638232
# MO     672772
# WA     730321
# TN     735102
# IN     753487
# AZ     808258
# VA     872376
# NJ     913330
# MI    1038080
# NC    1078680
# GA    1185168
# PA    1276091
# OH    1286370
# IL    1486991
# FL    1976379
# NY    2208154
# TX    3791675
# CA    5084647
# Name: Count, dtype: int64

# %% [markdown]
# ##### Выведите 5 наиболее популярных имен.

# %%
baby_names.groupby('Name')['Count'].sum().nlargest(5).to_frame()
# Out:
#            Count
# Name
# Jacob     242874
# Emma      214852
# Michael   214405
# Ethan     209277
# Isabella  204798

# %% [markdown]
# ##### Выведите 10 наименее популярных имен.

# %%
baby_names.groupby('Name')['Count'].sum().nlargest(10).to_frame()
# Out:
#            Count
# Name
# Jacob     242874
# Emma      214852
# Michael   214405
# Ethan     209277
# Isabella  204798
# William   197894
# Joshua    191551
# Sophia    191446
# Daniel    191440
# Emily     190318

# %% [markdown]
# ##### Выведите 5 наиболее популярных женских имен и 5 наиболее популярных мужских имен.

# %%
baby_names[baby_names['Gender'] == 'F'].groupby('Name')['Count'].sum().nlargest(5).to_frame()
# Out:
#            Count
# Name
# Emma      214757
# Isabella  204742
# Sophia    191421
# Emily     190211
# Olivia    187962

# %%
baby_names[baby_names['Gender'] == 'M'].groupby('Name')['Count'].sum().nlargest(5).to_frame()
# Out:
#           Count
# Name
# Jacob    242706
# Michael  214228
# Ethan    209153
# William  197796
# Joshua   191444

# %% [markdown]
# ##### Сколько различных имен существует в наборе данных?

# %%
baby_names['Name'].nunique()
# Out:
# 17632

# %% [markdown]
# ##### Выведите информацию о детях с именем Jacob

# %%
baby_names[baby_names['Name'] == 'Jacob']
# Out:
#           Name  Year Gender State  Count
# 2407     Jacob  2004      M    AK     54
# 2611     Jacob  2005      M    AK     58
# 2827     Jacob  2006      M    AK     55
# 3048     Jacob  2007      M    AK     49
# 3271     Jacob  2008      M    AK     60
# ...        ...   ...    ...   ...    ...
# 1015550  Jacob  2010      M    WY     21
# 1015708  Jacob  2011      M    WY     30
# 1015879  Jacob  2012      M    WY     28
# 1016056  Jacob  2013      M    WY     20
# 1016262  Jacob  2014      M    WY     13
#
# [568 rows x 5 columns]

# %% [markdown]
# ##### Выведите информацию о детях с именем Emma

# %%
# Out:
#          Name  Year Gender State  Count
# 103434   Emma  2014      F    CA   2662
# 99484    Emma  2013      F    CA   2478
# 95395    Emma  2012      F    CA   2449
# 882107   Emma  2014      F    TX   2177
# 91405    Emma  2011      F    CA   2115
# ...       ...   ...    ...   ...    ...
# 1013854  Emma  2010      F    WY     23
# 781940   Emma  2005      M    PA      6
# 788498   Emma  2010      M    PA      5
# 780877   Emma  2004      M    PA      5
# 693985   Emma  2013      M    NY      5
#
# [566 rows x 5 columns]

# %%
# Out:
#          Count     Name
# State
# AK       63649     Emma
# AL      475422     Emma
# AR      292659  Madison
# AZ      808258    Emily
# CA     5084647    Emily
# CO      574230     Emma
# CT      312747    Emily
# DC       82504   Sophia
# DE       73060  Madison
# FL     1976379    Emily

# %%
# Out:
#          Count
# State
# CA     5084647
# TX     3791675
# NY     2208154
# FL     1976379
# IL     1486991

# %%
# Out:
#                    Count
# State Name
# CA    Daniel       36772
#       Anthony      34113
#       Jacob        33819
#       Angel        31881
#       Isabella     31492
#       Sophia       30585
#       Emily        29838
#       David        29272
#       Andrew       28861
#       Matthew      28406
#       Alexander    28139
#       Ethan        27563
#       Joshua       26479
#       Michael      25945
#       Nathan       25188
#       Jose         25140
#       Christopher  24699
# TX    Jose         23934
# CA    Mia          23788
# TX    Jacob        23574
# CA    Jonathan     23236
#       Jayden       22840
#       Noah         22827
#       Joseph       22234
#       Emma         21522
#       Adrian       21220
# TX    Daniel       21085
# CA    Samantha     21073
# TX    Angel        20555
# CA    Isaac        20280
#       Ryan         20229
# TX    Emily        19869
#       David        19761
#       Isabella     19499
#       Joshua       19424
# ...
